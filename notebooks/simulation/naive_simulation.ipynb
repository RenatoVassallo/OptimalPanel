# %%
import numpy as np
import pandas as pd

# Set seed for reproducibility
np.random.seed(42)

# Simulation settings
years = np.arange(1980, 2025)
n_years = len(years)
units = ['A', 'B', 'C']
rho = 0.8  # AR coefficient
sigma_eps = 0.5
phi = 0.5  # AR(1) for x3
beta = np.array([0.5, 1.0, -0.5])  # Coefficients for x1, x2, x3

# Initialize data containers
data = []

# Simulate common x1 trend
x1 = np.zeros(n_years)
x1[0] = np.random.normal()
for t in range(1, n_years):
    x1[t] = x1[t - 1] + np.random.normal(scale=0.3)

# Simulate outbreak signal for x2 (predictive only for unit C)
signal = np.zeros(n_years)
signal_start = np.where(years == 2003)[0][0]
signal_peak = np.where(years == 2005)[0][0]
signal_end = np.where(years == 2010)[0][0]
signal[signal_start:signal_peak] = np.linspace(0, 1, signal_peak - signal_start)
signal[signal_peak:signal_end] = np.linspace(1, 0, signal_end - signal_peak)

# Simulate data for each unit
for unit in units:
    alpha = np.random.normal()
    y = np.zeros(n_years)
    y_lag = np.zeros(n_years)
    x2 = np.zeros(n_years)
    x3 = np.zeros(n_years)
    eps = np.random.normal(scale=sigma_eps, size=n_years)
    zeta = np.random.normal(scale=0.3, size=n_years)
    xi = np.random.normal(scale=0.2, size=n_years)

    x3[0] = np.random.normal()
    for t in range(1, n_years):
        x3[t] = phi * x3[t - 1] + zeta[t]

    # Assign x2 based on whether unit is predictive
    if unit == 'C':
        gamma = 1.0
    else:
        gamma = 0.0
    x2 = gamma * signal + xi

    # Initialize y[0]
    y[0] = alpha + beta @ np.array([x1[0], x2[0], x3[0]]) + eps[0]
    y_lag[0] = np.nan  # no lag at t=0

    for t in range(1, n_years):
        # Apply outbreak shocks
        delta = 0
        if unit == 'A' and 2015 <= years[t] <= 2020:
            delta = 3
        elif unit == 'C' and 2005 <= years[t] <= 2010:
            delta = 3

        y[t] = (
            alpha
            + rho * y[t - 1]
            + beta @ np.array([x1[t], x2[t], x3[t]])
            + delta
            + eps[t]
        )
        y_lag[t] = y[t - 1]

        data.append({
            'unit': unit,
            'year': years[t],
            'y': y[t],
            'y_lag': y_lag[t],
            'x1': x1[t],
            'x2': x2[t],
            'x3': x3[t],
            'delta': delta
        })

# Create DataFrame
df_sim = pd.DataFrame(data)
df_sim['year'] = pd.to_datetime(df_sim['year'], format='%Y')
df_sim
# Out:
#     unit       year         y     y_lag        x1        x2        x3  delta
# 0      A 1981-01-01 -0.052383 -0.429878  0.455235 -0.064412 -0.639195      0
# 1      A 1982-01-01  0.106480 -0.052383  0.649541  0.162703 -0.417896      0
# 2      A 1983-01-01 -1.045837  0.106480  1.106450 -0.246173 -0.326580      0
# 3      A 1984-01-01 -0.529706 -1.045837  1.036204  0.045492 -0.602345      0
# 4      A 1985-01-01 -0.485572 -0.529706  0.965963  0.261429 -0.212336      0
# ..   ...        ...       ...       ...       ...       ...       ...    ...
# 127    C 2020-01-01 -4.179262 -4.021869 -2.054402 -0.012536  0.103119      0
# 128    C 2021-01-01 -3.383287 -4.179262 -2.002992  0.191028 -0.268726      0
# 129    C 2022-01-01 -4.018603 -3.383287 -2.037686 -0.197145 -0.177077      0
# 130    C 2023-01-01 -4.081144 -4.018603 -2.128017  0.100809 -0.052450      0
# 131    C 2024-01-01 -4.505878 -4.081144 -2.571574 -0.106052  0.128107      0
#
# [132 rows x 8 columns]

# %%
# Plot "y" for each unit
import matplotlib.pyplot as plt
for unit in units:
    subset = df_sim[df_sim['unit'] == unit]
    plt.plot(subset['year'], subset['y'], label=f'Unit {unit}')
plt.title('Simulated Outcome Variable y by Unit')
plt.xlabel('Year')
plt.ylabel('Outcome Variable y')
plt.legend()
plt.show()

# %%
from OptimalPanel.optimizer import OptimalBundleRL

forecast_times = list(pd.date_range(start="2005-01-01", end="2014-01-01", freq="YS"))
total_epochs = 2000
    
rl = OptimalBundleRL(
    df=df_sim,
    unit_col='unit',
    time_col='year',
    target_col='y',
    feature_cols=['y_lag', 'x1', 'x2', 'x3'],
    target_unit='A',
    forecast_times=forecast_times
)

# %%
rl.compute_similarities(
    test_start=pd.to_datetime("1998-01-01"),
    test_end=pd.to_datetime("2004-01-01")
)
# Out:
# 🔍 Target: A — Top donor scores:
#   B: 0.5755
#   C: 0.1724
# (tensor([0.5755, 0.1724]), ['B', 'C'])

# %%
rl.train(
    n_epochs=total_epochs,
    save=False,
    save_path="results/annual/results_A.pkl"
)

rl.print_top_bundles(top_k=2)
rl.plot_learning_curve()
rl.plot_donor_probs(top_n=2)
# Out:
# Epoch 0 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 10 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 30 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 40 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 50 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 60 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 80 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 90 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 100 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 120 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 130 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 140 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 150 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 160 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 170 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 180 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 190 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 200 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 210 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 220 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 230 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 240 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 250 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 280 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 290 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 300 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 310 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 320 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 330 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 340 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 360 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 370 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 380 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 400 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 410 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 420 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 440 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 450 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 460 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 470 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 480 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 490 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 500 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 510 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 520 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 530 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 550 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 570 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 580 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 590 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 600 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 620 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 630 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 640 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 650 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 670 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 680 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 690 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 700 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 710 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 730 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 740 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 760 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 770 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 780 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 790 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 800 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 810 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 820 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 830 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 840 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 850 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 860 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 870 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 880 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 890 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 900 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 910 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 930 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 940 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 950 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 960 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 970 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 980 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 990 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1000 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1010 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1020 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1030 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1040 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1050 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1060 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1070 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1080 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1090 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1100 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1110 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1120 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1130 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1140 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1150 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1160 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1170 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1180 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1190 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1200 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1210 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1220 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1230 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1240 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1250 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1260 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1270 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1280 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1290 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1300 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1310 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1320 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1330 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1340 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1350 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1360 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1370 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1380 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1390 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1400 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1410 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1430 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1440 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1450 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1460 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1470 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1480 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1490 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1500 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1510 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1530 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1540 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1550 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1560 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1570 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1580 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1590 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1610 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1620 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1630 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1640 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1650 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1660 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1670 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1680 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1690 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1700 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1710 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1730 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1750 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1770 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1780 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1790 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1810 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1820 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1830 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1850 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1860 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1870 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1880 — Avg MSE: 1.5048, Bundle Size: 1
# Epoch 1890 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1900 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1910 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1920 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1930 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1940 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1950 — Avg MSE: 0.7727, Bundle Size: 2
# Epoch 1960 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1970 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1980 — Avg MSE: 0.7803, Bundle Size: 1
# Epoch 1990 — Avg MSE: 0.7727, Bundle Size: 2
# - Benchmark MSE (AR(1)): 0.5723334120266148
# - Benchmark MSE (Target only): 1.5324217359717536
# - Benchmark MSE (Full panel): 0.7726922611331634
# - Benchmark MSE (Best bundle): 0.7726922611331626
# - Training completed without saving results.
#
# 🔹 Top 2 Bundles by MSE:
# 1. Epoch  50 — MSE: 0.7727, Bundle: ['B', 'C']
# 2. Epoch 244 — MSE: 0.7727, Bundle: ['B', 'C']
